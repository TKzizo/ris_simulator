# %%
import pandas as pd
import math

# %%
# Read the simRIS values

## calculate the modulos of complex values
func = {c: lambda x: math.sqrt(complex(x).real**2 + complex(x).imag**2) for c in range(1000)}

H_simris = pd.read_csv("hj.csv",header=None,converters=func)
G_simris = pd.read_csv("gj.csv",header=None,converters=func)

print(H_simris)
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.000051  0.000078  0.000071  0.000053  0.000068  0.000035  0.000054
# 1     0.000052  0.000078  0.000071  0.000053  0.000068  0.000035  0.000052
# 2     0.000054  0.000079  0.000071  0.000054  0.000068  0.000035  0.000053
# 3     0.000056  0.000079  0.000071  0.000054  0.000068  0.000035  0.000050
# 4     0.000059  0.000080  0.000072  0.000054  0.000068  0.000035  0.000054
# ...        ...       ...       ...       ...       ...       ...       ...
# 4091  0.000069  0.000083  0.000067  0.000053  0.000068  0.000043  0.000054
# 4092  0.000070  0.000083  0.000066  0.000054  0.000068  0.000043  0.000053
# 4093  0.000070  0.000082  0.000066  0.000056  0.000068  0.000043  0.000051
# 4094  0.000068  0.000082  0.000066  0.000057  0.000068  0.000044  0.000050
# 4095  0.000066  0.000081  0.000066  0.000058  0.000068  0.000044  0.000050
#
# ...

# %%
# Read Our Simulator Values

# %%
# Run the Tests

# %%
# Plot the Results
